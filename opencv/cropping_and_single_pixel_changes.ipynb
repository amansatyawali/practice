# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
#Creating checkered image
# checkered_image = np.zeros((18, 18, 3), dtype = int)
# for i in range(6) :
#     for j in range(6, 12) :
#         checkered_image[i][j][0] = 255
#         checkered_image[i][j][1] = 255
#         checkered_image[i][j][2] = 255
        
# for i in range(6, 12) :
#     for j in list(range(6))+list(range(12, 18)) :
#         checkered_image[i][j][0] = 255
#         checkered_image[i][j][1] = 255
#         checkered_image[i][j][2] = 255
        
        
# for i in range(12, 18) :
#     for j in range(6, 12) :
#         checkered_image[i][j][0] = 255
#         checkered_image[i][j][1] = 255
#         checkered_image[i][j][2] = 255
        
        
# cv2.imwrite("small_checkered.jpg", checkered_image)
# Out:
# True

# %%
checkered_image = cv2.imread("small_checkered.jpg", 0)

# %%
plt.imshow(checkered_image, cmap = 'gray')

# %%
cp_image = checkered_image.copy()

cp_image[2][2] = 200
cp_image[2][3] = 200
cp_image[3][2] = 200
cp_image[3][3] = 200

# %%
plt.imshow(cp_image, cmap = 'gray')

# %%
bird_image_bgr = cv2.imread("index.png")
bird_image_rgb = bird_image_bgr[ : , : , :: -1]

# %%
plt.imshow(bird_image_rgb)

# %%
cropped_bird = bird_image_rgb[ 20 : 150 , 50 : 172 ]
plt.imshow(cropped_bird)
